# %%
import os
import numpy as np
import mne
# %matplotlib notebook

# %%
raw = mne.io.read_raw_fif('20211012_154603_AS14_Anschutz_Resting-EO_SL_raw.fif', verbose=True)
# Out:
# Opening raw data file 20211012_154603_AS14_Anschutz_Resting-EO_SL_raw.fif...
# Isotrak not found
#     Range : 0 ... 299999 =      0.000 ...   299.999 secs
# Ready.

# %%
#print(raw)
#print(raw.info)
#print(dir(raw))

# %%
raw.plot_psd(fmin=1, fmax=40, dB=False,estimate='auto', xscale='log')

#raw.plot(duration=100, n_channels=10)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Effective window size : 2.048 (s)
# <img src="data:image/png;base64,..." width="1000">

# %%
raw.to_data_frame()
# Out:
#           time    00:01-BZ_CL    00:02-BZ_CL    00:03-BZ_CL   00:04-BZ_CL  \
# 0            0 -179960.002385 -137280.001819 -100320.001330 -17600.000233
# 1            1 -179520.002379 -137280.001819 -100320.001330 -16280.000216
# 2            2 -179960.002385 -137720.001825  -99880.001324 -15400.000204
# 3            3 -179960.002385 -137280.001819  -99880.001324 -18480.000245
# 4            4 -180400.002391 -137280.001819  -99880.001324 -16720.000222
# ...        ...            ...            ...            ...           ...
# 299995  299995 -105600.001400  -59840.000793  -45320.000601  -5720.000076
# 299996  299996 -106040.001405  -61160.000811  -46200.000612  -7040.000093
# 299997  299997 -105160.001394  -60280.000799  -47520.000630  -5280.000070
# 299998  299998 -106040.001405  -60720.000805  -45320.000601  -3520.000047
# 299999  299999 -106480.001411  -60720.000805  -45760.000606  -3520.000047
#
#          00:05-BZ_CL    00:06-BZ_CL   00:07-BZ_CL   00:08-BZ_CL   00:09-BZ_CL  \
# ...
